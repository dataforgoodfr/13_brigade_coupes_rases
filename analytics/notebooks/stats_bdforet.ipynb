# %%
import geopandas as gpd

# %% [markdown]
# ## Load SUFOSAT clear-cuts enriched with BDFORET overlapping areas

# %%
gdf = gpd.read_file(
    "../../data_pipeline/bootstrap/data/sufosat/sufosat_clusters_enriched.fgb",
    columns=[
        "clear_cut_group",
        "area_ha",
        "bdf_deciduous_area_ha",
        "bdf_mixed_area_ha",
        "bdf_poplar_area_ha",
        "bdf_resinous_area_ha",
    ],
)
gdf
# Out:
#           area_ha  bdf_deciduous_area_ha  bdf_mixed_area_ha  \
# 0        0.520004                    NaN                NaN
# 1        0.520004                    NaN                NaN
# 2        0.060001                    NaN                NaN
# 3        0.920005                    NaN                NaN
# 4       11.550035                    NaN                NaN
# ...           ...                    ...                ...
# 255611   1.220009                    NaN           0.272163
# 255612   4.690016               3.731160                NaN
# 255613   1.100006                    NaN                NaN
# 255614   0.820007               0.675716                NaN
# 255615   1.810011               0.010764                NaN
#
#         bdf_poplar_area_ha  bdf_resinous_area_ha  clear_cut_group  \
# 0                      NaN                   NaN                0
# 1                      NaN                   NaN                1
# 2                      NaN                   NaN           239709
# 3                      NaN                   NaN                2
# 4                      NaN                   NaN                3
# ...                    ...                   ...              ...
# 255611                 NaN                   NaN           239704
# 255612                 NaN                   NaN           239706
# 255613                 NaN               1.06371           239705
# 255614                 NaN                   NaN           239707
# 255615                 NaN                   NaN           239708
#
#                                                  geometry
# 0       MULTIPOLYGON (((1219789.689 6054526.697, 12197...
# 1       MULTIPOLYGON (((1221859.689 6054536.697, 12218...
# 2       MULTIPOLYGON (((1221739.689 6054546.697, 12217...
# 3       MULTIPOLYGON (((1221159.688 6055586.697, 12211...
# 4       MULTIPOLYGON (((1219859.689 6055366.697, 12198...
# ...                                                   ...
# 255611  MULTIPOLYGON (((315009.689 6262906.697, 315009...
# 255612  MULTIPOLYGON (((315369.688 6261636.697, 315369...
# 255613  MULTIPOLYGON (((315689.689 6262016.697, 315689...
# 255614  MULTIPOLYGON (((314999.689 6264926.697, 314999...
# 255615  MULTIPOLYGON (((316729.689 6264726.697, 316729...
#
# [255616 rows x 7 columns]

# %% [markdown]
# ## Dealing with BDFORET data quality issues

# %%
f"{(gdf.isna().sum(axis=1) == 4).mean():.1%} of the clear-cuts don't overlap with any BDFORET polygon"
# Out:
# "12.5% of the clear-cuts don't overlap with any BDFORET polygon"

# %%
gdf["bdf_area_ha"] = (
    gdf["bdf_deciduous_area_ha"].fillna(0)
    + gdf["bdf_mixed_area_ha"].fillna(0)
    + gdf["bdf_poplar_area_ha"].fillna(0)
    + gdf["bdf_resinous_area_ha"].fillna(0)
)
gdf["bdf_coverage"] = gdf["bdf_area_ha"] / gdf["area_ha"]
gdf
# Out:
#           area_ha  bdf_deciduous_area_ha  bdf_mixed_area_ha  \
# 0        0.520004                    NaN                NaN
# 1        0.520004                    NaN                NaN
# 2        0.060001                    NaN                NaN
# 3        0.920005                    NaN                NaN
# 4       11.550035                    NaN                NaN
# ...           ...                    ...                ...
# 255611   1.220009                    NaN           0.272163
# 255612   4.690016               3.731160                NaN
# 255613   1.100006                    NaN                NaN
# 255614   0.820007               0.675716                NaN
# 255615   1.810011               0.010764                NaN
#
#         bdf_poplar_area_ha  bdf_resinous_area_ha  clear_cut_group  \
# 0                      NaN                   NaN                0
# 1                      NaN                   NaN                1
# 2                      NaN                   NaN           239709
# 3                      NaN                   NaN                2
# 4                      NaN                   NaN                3
# ...                    ...                   ...              ...
# 255611                 NaN                   NaN           239704
# 255612                 NaN                   NaN           239706
# 255613                 NaN               1.06371           239705
# 255614                 NaN                   NaN           239707
# 255615                 NaN                   NaN           239708
#
#                                                  geometry  bdf_area_ha  \
# 0       MULTIPOLYGON (((1219789.689 6054526.697, 12197...     0.000000
# 1       MULTIPOLYGON (((1221859.689 6054536.697, 12218...     0.000000
# 2       MULTIPOLYGON (((1221739.689 6054546.697, 12217...     0.000000
# 3       MULTIPOLYGON (((1221159.688 6055586.697, 12211...     0.000000
# 4       MULTIPOLYGON (((1219859.689 6055366.697, 12198...     0.000000
# ...                                                   ...          ...
# 255611  MULTIPOLYGON (((315009.689 6262906.697, 315009...     0.272163
# 255612  MULTIPOLYGON (((315369.688 6261636.697, 315369...     3.731160
# 255613  MULTIPOLYGON (((315689.689 6262016.697, 315689...     1.063710
# 255614  MULTIPOLYGON (((314999.689 6264926.697, 314999...     0.675716
# 255615  MULTIPOLYGON (((316729.689 6264726.697, 316729...     0.010764
#
#         bdf_coverage
# 0           0.000000
# 1           0.000000
# 2           0.000000
# 3           0.000000
# 4           0.000000
# ...              ...
# 255611      0.223082
# 255612      0.795554
# 255613      0.967004
# 255614      0.824037
# 255615      0.005947
#
# [255616 rows x 9 columns]

# %%
gdf[gdf["bdf_coverage"] > 0]["bdf_coverage"].describe().drop("count").apply(
    lambda x: f"{x:.0%}"
)
# Out:
# mean     86%
# std      26%
# min       0%
# 25%      84%
# 50%      96%
# 75%     100%
# max     200%
# Name: bdf_coverage, dtype: object

# %% [markdown]
# Among the clear-cuts overlapping with BDFORET, the average overlap is 86% of the clear-cut area, and the median overlap is 96%, that's great!
# However, the maximum coverage exceeds 100%, indicating that some BDFORET polygons representing different wood types overlap.
# That might be an issue...

# %%
gdf[gdf["bdf_coverage"] > 1]
# Out:
#          area_ha  bdf_deciduous_area_ha  bdf_mixed_area_ha  \
# 290     0.920007               0.754807           0.165199
# 291     0.670005               0.557268           0.112738
# 298     0.600007               0.600007                NaN
# 304     0.600005               0.189570           0.410435
# 305     0.980006               0.602087                NaN
# ...          ...                    ...                ...
# 255551  0.430004               0.280038                NaN
# 255552  0.670005               0.009178                NaN
# 255592  0.820005               0.607471           0.212534
# 255593  2.910010               1.030851                NaN
# 255604  1.600010               1.600010                NaN
#
#         bdf_poplar_area_ha  bdf_resinous_area_ha  clear_cut_group  \
# 290                    NaN                   NaN              282
# 291                    NaN                   NaN              283
# 298                    NaN                   NaN              288
# 304                    NaN                   NaN              295
# 305                    NaN              0.377919              297
# ...                    ...                   ...              ...
# 255551                 NaN              0.149966           239649
# 255552                 NaN              0.660827           239650
# 255592                 NaN                   NaN           239687
# 255593                 NaN              1.879159           239688
# 255604                 NaN                   NaN           235151
#
#                                                  geometry  bdf_area_ha  \
# 290     MULTIPOLYGON (((1168629.689 6157586.697, 11686...     0.920007
# 291     MULTIPOLYGON (((1168399.689 6157366.697, 11683...     0.670005
# 298     MULTIPOLYGON (((1167939.688 6170256.697, 11679...     0.600007
# 304     MULTIPOLYGON (((1175619.689 6179096.697, 11756...     0.600005
# 305     MULTIPOLYGON (((1174019.688 6178206.697, 11740...     0.980006
# ...                                                   ...          ...
# 255551  MULTIPOLYGON (((328419.689 6265316.697, 328419...     0.430004
# 255552  MULTIPOLYGON (((328369.689 6265246.697, 328369...     0.670005
# 255592  MULTIPOLYGON (((320739.688 6259476.697, 320709...     0.820005
# 255593  MULTIPOLYGON (((318499.688 6258166.697, 318489...     2.910010
# 255604  MULTIPOLYGON (((325569.689 6250766.697, 325569...     1.600010
#
#         bdf_coverage
# 290              1.0
# 291              1.0
# 298              1.0
# 304              1.0
# 305              1.0
# ...              ...
# 255551           1.0
# 255552           1.0
# 255592           1.0
# 255593           1.0
# 255604           1.0
#
# [24353 rows x 9 columns]

# %%
# Let's ignore the records with a coverage only slightly greater than 1
gdf[gdf["bdf_coverage"] > 1.001]
# Out:
#          area_ha  bdf_deciduous_area_ha  bdf_mixed_area_ha  \
# 1221    0.810005               0.348756           0.564119
# 1496    0.610005               0.666979                NaN
# 1662    3.120024                    NaN                NaN
# 1663    2.030013                    NaN           0.258696
# 1669    1.820007                    NaN                NaN
# ...          ...                    ...                ...
# 251582  1.130009               0.400579                NaN
# 251587  0.830007               0.809670                NaN
# 251621  1.130007               1.401339                NaN
# 251622  1.890012               2.123945                NaN
# 251623  5.280025               2.624091           1.422751
#
#         bdf_poplar_area_ha  bdf_resinous_area_ha  clear_cut_group  \
# 1221                   NaN                   NaN             1164
# 1496                   NaN                   NaN           239789
# 1662                   NaN              4.962028             1582
# 1663                   NaN              2.683765             1583
# 1669                   NaN              1.833747             1586
# ...                    ...                   ...              ...
# 251582            1.707437                   NaN           236241
# 251587                 NaN              0.024209           236246
# 251621                 NaN                   NaN           236279
# 251622                 NaN                   NaN           236278
# 251623                 NaN              1.522324           236280
#
#                                                  geometry  bdf_area_ha  \
# 1221    MULTIPOLYGON (((1015799.689 6281756.697, 10157...     0.912874
# 1496    MULTIPOLYGON (((1004129.688 6295976.697, 10041...     0.666979
# 1662    MULTIPOLYGON (((985539.689 6304406.697, 985539...     4.962028
# 1663    MULTIPOLYGON (((985579.688 6303766.697, 985569...     2.942461
# 1669    MULTIPOLYGON (((986279.689 6304506.697, 986279...     1.833747
# ...                                                   ...          ...
# 251582  MULTIPOLYGON (((381949.689 6278746.697, 381949...     2.108016
# 251587  MULTIPOLYGON (((382899.689 6279466.697, 382899...     0.833878
# 251621  MULTIPOLYGON (((384839.689 6279886.697, 384839...     1.401339
# 251622  MULTIPOLYGON (((384699.688 6279996.697, 384699...     2.123945
# 251623  MULTIPOLYGON (((385109.689 6280426.697, 385109...     5.569166
#
#         bdf_coverage
# 1221        1.126999
# 1496        1.093399
# 1662        1.590381
# 1663        1.449479
# 1669        1.007549
# ...              ...
# 251582      1.865487
# 251587      1.004664
# 251621      1.240115
# 251622      1.123773
# 251623      1.054761
#
# [3511 rows x 9 columns]

# %% [markdown]
# 3,500 clear-cuts have an abnormal coverage

# %%
gdf[
    (gdf["bdf_deciduous_area_ha"] > 1.001 * gdf["area_ha"])
    | (gdf["bdf_mixed_area_ha"] > 1.001 * gdf["area_ha"])
    | (gdf["bdf_poplar_area_ha"] > 1.001 * gdf["area_ha"])
    | (gdf["bdf_resinous_area_ha"] > 1.001 * gdf["area_ha"])
]
# Out:
#          area_ha  bdf_deciduous_area_ha  bdf_mixed_area_ha  \
# 1496    0.610005               0.666979                NaN
# 1662    3.120024                    NaN                NaN
# 1663    2.030013                    NaN           0.258696
# 1669    1.820007                    NaN                NaN
# 1670    1.710012                    NaN                NaN
# ...          ...                    ...                ...
# 251441  0.990008               1.868215                NaN
# 251518  2.830015               3.007410                NaN
# 251582  1.130009               0.400579                NaN
# 251621  1.130007               1.401339                NaN
# 251622  1.890012               2.123945                NaN
#
#         bdf_poplar_area_ha  bdf_resinous_area_ha  clear_cut_group  \
# 1496                   NaN                   NaN           239789
# 1662                   NaN              4.962028             1582
# 1663                   NaN              2.683765             1583
# 1669                   NaN              1.833747             1586
# 1670                   NaN              3.126222             1587
# ...                    ...                   ...              ...
# 251441                 NaN                   NaN           236109
# 251518                 NaN                   NaN           236179
# 251582            1.707437                   NaN           236241
# 251621                 NaN                   NaN           236279
# 251622                 NaN                   NaN           236278
#
#                                                  geometry  bdf_area_ha  \
# 1496    MULTIPOLYGON (((1004129.688 6295976.697, 10041...     0.666979
# 1662    MULTIPOLYGON (((985539.689 6304406.697, 985539...     4.962028
# 1663    MULTIPOLYGON (((985579.688 6303766.697, 985569...     2.942461
# 1669    MULTIPOLYGON (((986279.689 6304506.697, 986279...     1.833747
# 1670    MULTIPOLYGON (((985389.688 6304476.697, 985359...     3.126222
# ...                                                   ...          ...
# 251441  MULTIPOLYGON (((370649.689 6276446.697, 370649...     1.868215
# 251518  MULTIPOLYGON (((376169.689 6275106.697, 376169...     3.007410
# 251582  MULTIPOLYGON (((381949.689 6278746.697, 381949...     2.108016
# 251621  MULTIPOLYGON (((384839.689 6279886.697, 384839...     1.401339
# 251622  MULTIPOLYGON (((384699.688 6279996.697, 384699...     2.123945
#
#         bdf_coverage
# 1496        1.093399
# 1662        1.590381
# 1663        1.449479
# 1669        1.007549
# 1670        1.828188
# ...              ...
# 251441      1.887070
# 251518      1.062683
# 251582      1.865487
# 251621      1.240115
# 251622      1.123773
#
# [2789 rows x 9 columns]

# %% [markdown]
# It can also happen that only one wood essence area is larger than the clear-cut area, which means we can even have BDFORET polygons overlap for the same wood essence!
# This could be fixed by doing a dissolve operation on BDFORET before the JOIN.

# %% [markdown]
# For now, let's do a quick normalization fix to make sure that the coverage isn't greater than 100%

# %%
needs_to_be_normalized = gdf["bdf_coverage"] > 1
for bdf_col in [
    "bdf_deciduous_area_ha",
    "bdf_mixed_area_ha",
    "bdf_poplar_area_ha",
    "bdf_resinous_area_ha",
]:
    gdf.loc[needs_to_be_normalized, bdf_col] = (
        gdf.loc[needs_to_be_normalized, bdf_col]
        / gdf.loc[needs_to_be_normalized, "bdf_coverage"]
    )

# %%
gdf["bdf_area_ha"] = (
    gdf["bdf_deciduous_area_ha"].fillna(0)
    + gdf["bdf_mixed_area_ha"].fillna(0)
    + gdf["bdf_poplar_area_ha"].fillna(0)
    + gdf["bdf_resinous_area_ha"].fillna(0)
)
gdf["bdf_coverage"] = gdf["bdf_area_ha"] / gdf["area_ha"]
gdf
# Out:
#           area_ha  bdf_deciduous_area_ha  bdf_mixed_area_ha  \
# 0        0.520004                    NaN                NaN
# 1        0.520004                    NaN                NaN
# 2        0.060001                    NaN                NaN
# 3        0.920005                    NaN                NaN
# 4       11.550035                    NaN                NaN
# ...           ...                    ...                ...
# 255611   1.220009                    NaN           0.272163
# 255612   4.690016               3.731160                NaN
# 255613   1.100006                    NaN                NaN
# 255614   0.820007               0.675716                NaN
# 255615   1.810011               0.010764                NaN
#
#         bdf_poplar_area_ha  bdf_resinous_area_ha  clear_cut_group  \
# 0                      NaN                   NaN                0
# 1                      NaN                   NaN                1
# 2                      NaN                   NaN           239709
# 3                      NaN                   NaN                2
# 4                      NaN                   NaN                3
# ...                    ...                   ...              ...
# 255611                 NaN                   NaN           239704
# 255612                 NaN                   NaN           239706
# 255613                 NaN               1.06371           239705
# 255614                 NaN                   NaN           239707
# 255615                 NaN                   NaN           239708
#
#                                                  geometry  bdf_area_ha  \
# 0       MULTIPOLYGON (((1219789.689 6054526.697, 12197...     0.000000
# 1       MULTIPOLYGON (((1221859.689 6054536.697, 12218...     0.000000
# 2       MULTIPOLYGON (((1221739.689 6054546.697, 12217...     0.000000
# 3       MULTIPOLYGON (((1221159.688 6055586.697, 12211...     0.000000
# 4       MULTIPOLYGON (((1219859.689 6055366.697, 12198...     0.000000
# ...                                                   ...          ...
# 255611  MULTIPOLYGON (((315009.689 6262906.697, 315009...     0.272163
# 255612  MULTIPOLYGON (((315369.688 6261636.697, 315369...     3.731160
# 255613  MULTIPOLYGON (((315689.689 6262016.697, 315689...     1.063710
# 255614  MULTIPOLYGON (((314999.689 6264926.697, 314999...     0.675716
# 255615  MULTIPOLYGON (((316729.689 6264726.697, 316729...     0.010764
#
#         bdf_coverage
# 0           0.000000
# 1           0.000000
# 2           0.000000
# 3           0.000000
# 4           0.000000
# ...              ...
# 255611      0.223082
# 255612      0.795554
# 255613      0.967004
# 255614      0.824037
# 255615      0.005947
#
# [255616 rows x 9 columns]

# %%
gdf[gdf["bdf_coverage"] > 1.00000001]  # slightly above 1 for float summing errors
# Out:
# Empty GeoDataFrame
# Columns: [area_ha, bdf_deciduous_area_ha, bdf_mixed_area_ha, bdf_poplar_area_ha, bdf_resinous_area_ha, clear_cut_group, geometry, bdf_area_ha, bdf_coverage]
# Index: []

# %% [markdown]
# Now that we fixed this issue, let's do the stats again

# %%
gdf[gdf["bdf_coverage"] > 0]["bdf_coverage"].describe().drop("count").apply(
    lambda x: f"{x:.0%}"
)
# Out:
# mean     85%
# std      25%
# min       0%
# 25%      84%
# 50%      96%
# 75%     100%
# max     100%
# Name: bdf_coverage, dtype: object

# %% [markdown]
# So now the mean coverage is 85% and the median coverage is 96%, that's still pretty good!

# %% [markdown]
# ## Combination of BDFORET overlaps

# %%
threshold = 0.1
gdf["combination"] = ""
for bdf_col in ["deciduous", "mixed", "poplar", "resinous"]:
    gdf.loc[
        ((gdf[f"bdf_{bdf_col}_area_ha"] / gdf["area_ha"]) > threshold), "combination"
    ] = gdf["combination"] + f" {bdf_col}"
gdf["combination"] = gdf["combination"].str.split().str.join(" - ")
combination_vc = gdf["combination"].value_counts()
combination_vc
# Out:
# combination
# deciduous                                88562
# resinous                                 53057
#                                          41120
# mixed                                    19362
# poplar                                   17102
# deciduous - resinous                     11636
# deciduous - mixed                         7841
# deciduous - poplar                        7539
# mixed - resinous                          7252
# deciduous - mixed - resinous              1428
# mixed - poplar                             244
# poplar - resinous                          243
# deciduous - poplar - resinous              120
# deciduous - mixed - poplar                  79
# mixed - poplar - resinous                   21
# deciduous - mixed - poplar - resinous       10
# Name: count, dtype: int64

# %%
single_essence = combination_vc.loc[
    ["deciduous", "resinous", "mixed", "poplar"]
].sum() / len(gdf)
print(
    f"{single_essence:.0%} of the clear-cuts overlap with a single wood essence (> {threshold:.0%})"
)
# Out:
# 70% of the clear-cuts overlap with a single wood essence (> 10%)

# %%
missing_bdforet = combination_vc.loc[""] / len(gdf)
print(
    f"{missing_bdforet:.0%} of the clear-cuts don't overlap with any wood essence (> {threshold:.0%})"
)
# Out:
# 16% of the clear-cuts don't overlap with any wood essence (> 10%)
